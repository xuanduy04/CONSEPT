# %% [markdown]
# Note: This is ment to be ran on Google Collab

# %% [markdown]
# # Mount drive

# %%
mount_drive = False
drive_path = '/content/drive'

import os
from google.colab import drive
if mount_drive and (not os.path.exists(drive_path)):
  drive.mount(drive_path)

# %% [markdown]
# # Pull repo

# %%
# !hf auth login --token "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"
# !hf auth whoami
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `hf`CLI if you want to set the git credential as well.
# Token is valid (permission: write).
# The token `AllPowerful` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `AllPowerful`
# user:  xuanduy04
# orgs:  vntc2

# %%
import os

repository = 'CONSEPT'
repo_path = f'/content/{repository}'

if not os.path.exists(repo_path):
  token = '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'
  username = 'xuanduy04'
  target_folder = repository

  repository_url_with_token = f'https://{token}@github.com/{username}/{repository}.git'

  # !git clone {repository_url_with_token} {target_folder}
  # %cd $repo_path
else:
  # %cd $repo_path
  # !git reset --hard HEAD
  # !git clean -df
  # !git pull
# Out:
# Cloning into 'CONSEPT'...
# remote: Enumerating objects: 432, done.
# remote: Counting objects: 100% (432/432), done.
# remote: Compressing objects: 100% (288/288), done.
# remote: Total 432 (delta 155), reused 401 (delta 124), pack-reused 0 (from 0)
# Receiving objects: 100% (432/432), 1.33 MiB | 5.13 MiB/s, done.
# Resolving deltas: 100% (155/155), done.
# /content/CONSEPT

# %%
# !git checkout 'dev'
# !git branch
# Out:
# Branch 'dev' set up to track remote branch 'dev' from 'origin'.
# Switched to a new branch 'dev'
# * dev
#   main

# %%
train_path = repo_path + "/examples"

# %% [markdown]
# #install requirements

# %%
# %%time
# !pip install -q trl==0.24.0
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 4.3 MB/s eta 0:00:00a 0:00:01
# CPU times: user 1.46 s, sys: 213 ms, total: 1.67 s
# Wall time: 6.79 s

# %% [markdown]
# # Main

# %%
# %cd $train_path
# !bash scripts/debug_consept_cpu.sh
# Out:
# /content/CONSEPT/examples
# Resolving data files: 100% 18/18 [00:00<00:00, 100797.69it/s]
# Loading weights: 100% 310/310 [00:00<00:00, 872.29it/s, Materializing param=model.norm.weight]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
# Traceback (most recent call last):
#   File "/content/CONSEPT/examples/main/consept_main.py", line 103, in <module>
#     trainer.train()
#   File "/usr/local/lib/python3.12/dist-packages/transformers/trainer.py", line 2174, in train
#     return inner_training_loop(
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/trainer.py", line 2267, in _inner_training_loop
#     ) = self.set_initial_training_values(args, train_dataloader, total_train_batch_size)
# ...
